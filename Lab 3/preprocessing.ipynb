# %%
import pandas as pd

# %%
df = pd.read_csv('./data/all_fc_24_players.csv')
df
# Out:
#        Unnamed: 0               name         nation               club  \
# 0               0      Kylian Mbappé         France           Paris SG
# 1               1    Alexia Putellas          Spain       FC Barcelona
# 2               2     Erling Haaland         Norway    Manchester City
# 3               3    Kevin De Bruyne        Belgium    Manchester City
# 4               4     Aitana Bonmatí          Spain       FC Barcelona
# ...           ...                ...            ...                ...
# 18091       18091    Ashley Lawrence         Canada            Chelsea
# 18092       18092    Mallory Swanson  United States  Chicago Red Stars
# 18093       18093  Wojciech Szczęsny         Poland           Juventus
# 18094       18094  Cristiana Girelli          Italy           Juventus
# 18095       18095      Jack Grealish        England    Manchester City
#
#       position alternative positions  age  overall  PAC  SHO  ...  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# name                         0
# nation                       0
# club                         0
# position                     0
# alternative positions        0
# age                          0
# overall                      0
# PAC                          0
# SHO                          0
# PAS                          0
# DRI                          0
# DEF                          0
# PHY                          0
# Acceleration                 0
# Sprint Speed                 0
# Positioning                  0
# Finishing                    0
# Shot Power                   0
# Long Shots                   0
# Volleys                      0
# Penalties                    0
# Vision                       0
# Crossing                     0
# Free Kick Accuracy           0
# Short Passing                0
# Long Passing                 0
# Curve                        0
# Agility                      0
# Balance                      0
# ...

# %%
df[['GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes']] = df[['GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes']].fillna(0)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'nation', 'club', 'position',
#        'alternative positions', 'age', 'overall', 'PAC', 'SHO', 'PAS', 'DRI',
#        'DEF', 'PHY', 'Acceleration', 'Sprint Speed', 'Positioning',
#        'Finishing', 'Shot Power', 'Long Shots', 'Volleys', 'Penalties',
#        'Vision', 'Crossing', 'Free Kick Accuracy', 'Short Passing',
#        'Long Passing', 'Curve', 'Agility', 'Balance', 'Reactions',
#        'Ball Control', 'Dribbling', 'Composure', 'Interceptions',
#        'Heading Accuracy', 'Def Awareness', 'Standing Tackle',
#        'Sliding Tackle', 'Jumping', 'Stamina', 'Strength', 'Aggression',
#        'height', 'weight', 'preferred foot', 'weak foot', 'league',
#        'att work rate', 'def work rate', 'skill moves', 'url', 'GK Diving',
#        'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Gender'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0', 'url'])

# %%
df
# Out:
#                     name         nation               club position  \
# 0          Kylian Mbappé         France           Paris SG       ST
# 1        Alexia Putellas          Spain       FC Barcelona       CM
# 2         Erling Haaland         Norway    Manchester City       ST
# 3        Kevin De Bruyne        Belgium    Manchester City       CM
# 4         Aitana Bonmatí          Spain       FC Barcelona       CM
# ...                  ...            ...                ...      ...
# 18091    Ashley Lawrence         Canada            Chelsea       RB
# 18092    Mallory Swanson  United States  Chicago Red Stars       LW
# 18093  Wojciech Szczęsny         Poland           Juventus       GK
# 18094  Cristiana Girelli          Italy           Juventus       ST
# 18095      Jack Grealish        England    Manchester City       LW
#
#       alternative positions  age  overall  PAC  SHO  PAS  ...  \
# 0                ST, LW, CF   25       91   97   90   80  ...
# ...

# %%
df.dtypes
# Out:
# name                      object
# nation                    object
# club                      object
# position                  object
# alternative positions     object
# age                        int64
# overall                    int64
# PAC                        int64
# SHO                        int64
# PAS                        int64
# DRI                        int64
# DEF                        int64
# PHY                        int64
# Acceleration               int64
# Sprint Speed               int64
# Positioning                int64
# Finishing                  int64
# Shot Power                 int64
# Long Shots                 int64
# Volleys                    int64
# Penalties                  int64
# Vision                     int64
# Crossing                   int64
# Free Kick Accuracy         int64
# Short Passing              int64
# Long Passing               int64
# Curve                      int64
# Agility                    int64
# ...

# %%
df.to_csv('fc_24_players_preprocessed.csv')
